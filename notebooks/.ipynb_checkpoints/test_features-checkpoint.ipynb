# %%
import numpy as np
import pickle

# %matplotlib inline
import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('../')
import scripts.map_and_average as mapper
import scripts.load_features as load_features
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# /Applications/anaconda/lib/python2.7/site-packages/librosa/core/audio.py:33: UserWarning: Could not import scikits.samplerate. Falling back to scipy.signal
#   warnings.warn('Could not import scikits.samplerate. '

# %%
feat_loader = load_features.FeatureLoader()

# %%
op, mfcc = feat_loader.get_op_mfcc_for_file(melspec_file=
                        '../data/sample_dataset/Melspec/mel_1_2_1.csv')

plt.figure()
plt.imshow(op, aspect='auto')
plt.figure()
plt.imshow(mfcc, aspect='auto')
# Out:
# extracting onset patterns and mfccs...

# %%
chroma = feat_loader.get_chroma_for_file(chroma_file=
                        '../data/sample_dataset/Chroma/mel_1_2_1.csv')
plt.figure()
plt.imshow(chroma, aspect='auto')
# Out:
# extracting chroma...

# %%
pb = feat_loader.get_pb_from_melodia(melodia_file=
                         '../data/sample_dataset/Melodia/mel_1_2_1.csv', 
                         nmfpb=False, scale=False)
plt.figure()
plt.imshow(pb, aspect='auto')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-260e7e3869db> in <module>()
# ----> 1 pb = get_pb_from_melodia(melodia_file=
#       2                          '../data/sample_dataset/Melodia/mel_1_2_1.csv',
#       3                          nmfpb=False, scale=False)
#       4 plt.figure()
#       5 plt.imshow(pb, aspect='auto')
#
# NameError: name 'get_pb_from_melodia' is not defined
