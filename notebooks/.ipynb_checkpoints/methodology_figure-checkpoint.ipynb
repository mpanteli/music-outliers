# %%
import numpy as np
import pandas as pd

# %matplotlib inline
import matplotlib.pyplot as plt

import sys
sys.path.append('../')

# %%
chroma_file = '../data/sample_dataset/Chroma/mel_1_2_1.csv'
melspec_file = '../data/sample_dataset/Melspec/mel_1_2_1.csv'

# %%
chroma = pd.read_csv(chroma_file, header=None)
print chroma.shape
plt.imshow(chroma.T, aspect='auto')
plt.xticks([])
plt.yticks([])
#plt.xlabel('Time')
#plt.ylabel('Pitch-class')
plt.savefig('chroma.pdf')
plt.savefig('chroma.png')
# Out:
# (2245, 60)

# %%
melspec = pd.read_csv(melspec_file, header=None)
print melspec.shape
plt.imshow(melspec.T, aspect='auto')
plt.xticks([])
plt.yticks([])
#plt.xlabel('Time')
#plt.ylabel('Mel-frequency')
plt.savefig('melspec.pdf')
plt.savefig('melspec.png')
# Out:
# (2245, 40)
